# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp

# %pylab inline

n = 100
drinks = ['gin', 'vodka','rum', 'tequila', 'whiskey']
drink_weights = [0.3, 0.15, 0.1, 0.35, 0.1]

drink_draws = np.random.choice(drinks, size=n, p=drink_weights)

fig, ax = plt.subplots(figsize=(14,8))

pd.Series(drink_draws).value_counts().plot(kind='bar', ax=ax, color='y')

ax.set_title('What do people drink?')
ax.set_xlabel('Drinks')
ax.set_ylabel('Frequency of orders')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Text(0,0.5,'Frequency of orders')
